# %%
# BMI body mas index

height = int(input('What is your height?'))
weight= int(input('what is your weight?'))
name = input ('what is your name?')
BMI = weight/height**2
print("My name is",name,'and my BMI is',BMI)
# Out:
# What is your height?1212
# what is your weight?12
# what is your name?sasds
# My name is sasds and my BMI is 8.169133745057675e-06

# %% [markdown]
# * Categorical Variable
# * Continuous Variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=1,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\sartaj ahmed\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: six in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sartaj ahmed\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(sns.utils.get_data_home())
iris= sns.load_dataset("iris", cache=True)
iris
# Out:
# C:\Users\Sartaj Ahmed\seaborn-data
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x ="sepal.length", y ="sepal.width",data=iris)
plt.title("Iris Plot")
plt.xlim(2)
plt.ylim(2)
plt.show()
