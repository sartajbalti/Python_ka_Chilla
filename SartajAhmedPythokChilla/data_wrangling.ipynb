# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
kashti = sns.load_dataset('titanic')
ks1 = kashti 
ks2 = kashti

# %%
kashti.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
(kashti['age']+1).head(10)
# Out:
# 0    23.0
# 1    39.0
# 2    27.0
# 3    36.0
# 4    36.0
# 5     NaN
# 6    55.0
# 7     3.0
# 8    28.0
# 9    15.0
# Name: age, dtype: float64

# %%
kashti.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.shape
# Out:
# (891, 16)

# %%
kashti.dropna(subset=['deck'],axis=0, inplace=True)

# %%
kashti.isnull().sum()
# Out:
# Unnamed: 0      0
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
kashti.dropna()
kashti.dropna().isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# Out:
# (203, 16)

# %%
ks1.isnull().sum()
# Out:
# Unnamed: 0      0
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
mean = ks1['age'].mean()

# %%
ks1['age'] = ks1['age'].replace(np.nan, mean)

# %%
ks1.isnull().sum()
# Out:
# Unnamed: 0     0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
ks1.shape
# Out:
# (203, 16)

# %%
ks1.dtypes
# Out:
# Unnamed: 0        int64
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1['survived'] = ks1['survived'].astype('float64')
ks1.dtypes
# Out:
# Unnamed: 0        int64
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1['age'] = ks1['age']*356

# %%
ks1.head(5)
# Out:
#     Unnamed: 0  survived  pclass     sex      age  sibsp  parch     fare  \
# 1            1       1.0       1  female  13528.0      1      0  71.2833
# 3            3       1.0       1  female  12460.0      1      0  53.1000
# 6            6       0.0       1    male  19224.0      0      0  51.8625
# 10          10       1.0       3  female   1424.0      1      1  16.7000
# 11          11       1.0       1  female  20648.0      0      0  26.5500
#
#    embarked  class    who  adult_male deck  embark_town alive  alone
# 1         C  First  woman       False    C    Cherbourg   yes  False
# 3         S  First  woman       False    C  Southampton   yes  False
# 6         S  First    man        True    E  Southampton    no   True
# 10        S  Third  child       False    G  Southampton   yes  False
# 11        S  First  woman       False    C  Southampton   yes   True

# %%
ks1.rename(columns={"age": "age in days"}, inplace=True)
ks1.head(5)
# Out:
#     Unnamed: 0  survived  pclass     sex  age in days  sibsp  parch     fare  \
# 1            1       1.0       1  female      13528.0      1      0  71.2833
# 3            3       1.0       1  female      12460.0      1      0  53.1000
# 6            6       0.0       1    male      19224.0      0      0  51.8625
# 10          10       1.0       3  female       1424.0      1      1  16.7000
# 11          11       1.0       1  female      20648.0      0      0  26.5500
#
#    embarked  class    who  adult_male deck  embark_town alive  alone
# 1         C  First  woman       False    C    Cherbourg   yes  False
# 3         S  First  woman       False    C  Southampton   yes  False
# 6         S  First    man        True    E  Southampton    no   True
# 10        S  Third  child       False    G  Southampton   yes  False
# 11        S  First  woman       False    C  Southampton   yes   True

# %%
ks3 = ks1[['age in days', 'fare']]
ks3.head(5)
# Out:
#     age in days     fare
# 1       13528.0  71.2833
# 3       12460.0  53.1000
# 6       19224.0  51.8625
# 10       1424.0  16.7000
# 11      20648.0  26.5500

# %%
ks3['fare'] = ks3['fare']/ks3['fare'].max()
ks3.head()
# Out:
# C:\Users\Sartaj\AppData\Local\Temp\ipykernel_8184\239786220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks3['fare'] = ks3['fare']/ks3['fare'].max()
#     age in days      fare
# 1       13528.0  0.139136
# 3       12460.0  0.103644
# 6       19224.0  0.101229
# 10       1424.0  0.032596
# 11      20648.0  0.051822

# %%
# Simple feature scaling
ks3['age in days'] = ks3['age in days']/ks3['age in days'].max()
ks3.head()
# Out:
# C:\Users\Sartaj\AppData\Local\Temp\ipykernel_8184\219023598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks3['age in days'] = ks3['age in days']/ks3['age in days'].max()
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %%
# mean max method

# %%
ks3['fare'] = (ks3['fare']-ks3['fare'].min())/(ks3['fare'].max()-ks3['fare'].min())
ks3.head()
# Out:
# C:\Users\Sartaj\AppData\Local\Temp\ipykernel_8184\4011695959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks3['fare'] = (ks3['fare']-ks3['fare'].min())/(ks3['fare'].max()-ks3['fare'].min())
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %%
# z_score
ks3['fare'] = (ks3['fare']-ks3['fare'].mean())/ks3['fare'].std()
ks3.head()
# Out:
# C:\Users\Sartaj\AppData\Local\Temp\ipykernel_8184\130998099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks3['fare'] = (ks3['fare']-ks3['fare'].mean())/ks3['fare'].std()
#     age in days      fare
# 1        0.4750 -0.067879
# 3        0.4375 -0.311883
# 6        0.6750 -0.328489
# 10       0.0500 -0.800339
# 11       0.7250 -0.668161

# %%
# Log transformation 
ks = sns.load_dataset('titanic')
ks.head(5)
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
ks['fare'] = np.log(ks['fare'])
ks.head()
# Out:
# C:\Users\Sartaj\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 0           0         0       3    male  22.0      1      0  1.981001
# 1           1         1       1  female  38.0      1      0  4.266662
# 2           2         1       3  female  26.0      0      0  2.070022
# 3           3         1       1  female  35.0      1      0  3.972177
# 4           4         0       3    male  35.0      0      0  2.085672
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
#Binning 
bins = np.linspace(min(ks['age']),max(ks['age']), 15000000)
age_groups = ["Bachy", "Jawan", "Buzruk"]
ks['age'] = pd.cut(ks['age'], bins, labels=age_groups, include_lowest=True)
ks['age']

# %%
pd.get_dummies(ks['sex'])
ks.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 0           0         0       3    male  22.0      1      0  1.981001
# 1           1         1       1  female  38.0      1      0  4.266662
# 2           2         1       3  female  26.0      0      0  2.070022
# 3           3         1       1  female  35.0      1      0  3.972177
# 4           4         0       3    male  35.0      0      0  2.085672
#
#   embarked  class    who  adult_male deck  embark_town alive  alone
# 0        S  Third    man        True  NaN  Southampton    no  False
# 1        C  First  woman       False    C    Cherbourg   yes  False
# 2        S  Third  woman       False  NaN  Southampton   yes   True
# 3        S  First  woman       False    C  Southampton   yes  False
# 4        S  Third    man        True  NaN  Southampton    no   True

# %%
dum = pd.get_dummies(ks['sex'])
dum
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]
