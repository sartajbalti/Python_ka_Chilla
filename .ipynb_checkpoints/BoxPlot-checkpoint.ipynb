# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic=sns.load_dataset("titanic",cache=True)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
from numpy import mean
sns.set_style(style=None, rc=None)
sns.set_style("darkgrid")
sns.boxplot(x="class",y="fare", hue="sex", data=titanic, palette="Spectral", saturation=10)
plt.show()

# %%
import pandas as pd
import numpy as np
tip=sns.load_dataset("tips",cache=True)
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(x="day",y="tip", data=tip, palette="Spectral", saturation=10)
plt.title("Daily Tips Details")
plt.show()

# %%
plt.title("Daily Tips Details")
sns.boxplot(x="tip",y="day", data=tip,hue="smoker", palette="Set2", dodge=True)
# Out:
# <AxesSubplot:title={'center':'Daily Tips Details'}, xlabel='tip', ylabel='day'>

# %%
plt.title("Daily Tips Details")
sns.boxplot(x="tip",y="day", data=tip,hue="smoker", palette="Set2",dodge=False)
# Out:
# <AxesSubplot:title={'center':'Daily Tips Details'}, xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
fig, ax = plt.subplots()

a = pd.DataFrame({'Program': ['A', 'A', 'B', 'B', 'Total', 'Total'],
                  'Scenario': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
                  'Duration': [4, 3, 5, 4, 9, 7]})
b = pd.DataFrame({'Program': ['A', 'A', 'B', 'B', 'C', 'C', 'Total', 'Total'],
                  'Scenario': ['X', 'Y', 'X', 'Y', 'X', 'Y', 'X', 'Y'],
                  'Duration': [4, 3, 5, 4, 3, 2, 12, 9]})

unique = a["Program"].append(b["Program"]).unique()
palette = dict(zip(unique, sns.color_palette(n_colors=len(unique))))
palette.update({"Total":"k"})

ax = sns.barplot(data=a, x='Scenario', y='Duration',
                 hue='Program', ci=None, palette=palette)
plt.tight_layout()
plt.figure()

ax2 = sns.barplot(data=b, x='Scenario', y='Duration',
                  hue='Program', ci=None,  palette=palette)
plt.tight_layout()
plt.show()

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
p1=sns.boxplot(x="sex", y = "fare", data=titanic, showmeans=True, meanprops={"marker":"*","markersize":"12"})

# %%
# Out:
#   File "C:\Users\SARTAJ~1\AppData\Local\Temp/ipykernel_6956/1251628881.py", line 1
#     p1+showmean =True
#     ^
# SyntaxError: cannot assign to operator
